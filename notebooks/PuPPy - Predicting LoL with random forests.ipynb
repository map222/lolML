# %% [markdown]
# #  Predicting winners in League of Legends using random forests
#
# Michael Patterson
#
# github.com/map222/lolML

# %%
import requests, json
import numpy as np
from lolML.src import API_io
import importlib
import pandas as pd
import pickle
import os
from lolML.src import feature_calc
import matplotlib.pyplot as plt
import lolML.src.plotting as lol_plt
# %matplotlib inline
import pdb

# %%
working_dir = 'C:\\Users\\Chauncey\\Documents\\GitHub\\lolML'
os.chdir(working_dir)
with open(working_dir+ '\\api_key.txt', 'r') as api_file:
    api_key =  api_file.read()

# %%
with open('EUW combined_df.pickle', 'rb') as pickle_file:
    euw_timelines_df = pickle.load(pickle_file)
with open('KR combined_df.pickle', 'rb') as pickle_file:
    kr_timelines_df = pickle.load(pickle_file)
with open('NA combined_df.pickle', 'rb') as pickle_file:
    na_timelines_df = pickle.load(pickle_file)
with open('Season 2015 Team ranked combined_df.pickle', 'rb') as pickle_file:
    team_timelines_df = pickle.load(pickle_file)

# %%
# load sklearn package 
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
from sklearn import cross_validation
from sklearn.ensemble import RandomForestClassifier

# %%
euw_timelines_df = [feature_calc.calc_secondary_features(x) for x in euw_timelines_df]
na_timelines_df = [feature_calc.calc_secondary_features(x) for x in na_timelines_df]
kr_timelines_df = [feature_calc.calc_secondary_features(x) for x in kr_timelines_df]
team_timelines_df = [feature_calc.calc_secondary_features(x) for x in team_timelines_df]
euw_timelines_df = feature_calc.calc_second_diff(euw_timelines_df)
na_timelines_df = feature_calc.calc_second_diff(na_timelines_df)
kr_timelines_df = feature_calc.calc_second_diff(kr_timelines_df)
team_timelines_df = feature_calc.calc_second_diff(team_timelines_df)

# %%
import matplotlib as mpl
mpl.rc('font', size=22)
mpl.rc('lines', linewidth=3)
mpl.rc('figure',figsize=[8, 6])

# %% [markdown]
# # Use Riot's API to download JSON Data

# %%
# loading the pickle in
with open('full match info.pickle', 'rb') as pickle_file:
    full_match_info = pickle.load(pickle_file)
    match_info = full_match_info[0]

# %%
match_info = requests.get(match_urls[cur_match],
                          match_info_params)

# %%
match_info.json()
# Out:
# {'mapId': 11,
#  'matchCreation': 1442681043081,
#  'matchDuration': 2160,
#  'matchId': 1955239698,
#  'matchMode': 'CLASSIC',
#  'matchType': 'MATCHED_GAME',
#  'matchVersion': '5.18.0.297',
#  'participantIdentities': [{'participantId': 1,
#    'player': {'matchHistoryUri': '/v1/stats/player_history/NA/36154943',
#     'profileIcon': 575,
#     'summonerId': 22403576,
#     'summonerName': 'Pants are Dragon'}},
#   {'participantId': 2,
#    'player': {'matchHistoryUri': '/v1/stats/player_history/NA1/46840062',
#     'profileIcon': 7,
#     'summonerId': 31937841,
#     'summonerName': 'IRL 54bomb99'}},
#   {'participantId': 3,
#    'player': {'matchHistoryUri': '/v1/stats/player_history/NA/33661240',
#     'profileIcon': 752,
#     'summonerId': 20616684,
#     'summonerName': 'Drunken Immortal'}},
#   {'participantId': 4,
#    'player': {'matchHistoryUri': '/v1/stats/player_history/NA1/45192236',
#     'profileIcon': 523,
#     'summonerId': 30871780,
#     'summonerName': 'CloudNguyen'}},
#   {'participantId': 5,
#    'player': {'matchHistoryUri': '/v1/stats/player_history/NA1/47877977',
#     'profileIcon': 752,
#     'summonerId': 32867184,
#     'summonerName': 'Blitzt  Kappa'}},
#   {'participantId': 6,
#    'player': {'matchHistoryUri': '/v1/stats/player_history/NA1/216210463',
#     'profileIcon': 750,
#     'summonerId': 53407717,
#     'summonerName': 'hi im gosupport'}},
#   {'participantId': 7,
#    'player': {'matchHistoryUri': '/v1/stats/player_history/NA1/209701099',
#     'profileIcon': 6,
#     'summonerId': 46810093,
#     'summonerName': 'Commando Annie'}},
#   {'participantId': 8,
#    'player': {'matchHistoryUri': '/v1/stats/player_history/NA1/201541446',
#     'profileIcon': 588,
#     'summonerId': 38809624,
#     'summonerName': 'Sophist Sage'}},
#   {'participantId': 9,
#    'player': {'matchHistoryUri': '/v1/stats/player_history/NA/39254475',
#     'profileIcon': 642,
#     'summonerId': 24803075,
#     'summonerName': 'Chibify'}},
#   {'participantId': 10,
#    'player': {'matchHistoryUri': '/v1/stats/player_history/NA1/42537735',
#     'profileIcon': 903,
#     'summonerId': 28329804,
#     'summonerName': 'Moraitis'}}],
#  'participants': [{'championId': 62,
#    'highestAchievedSeasonTier': 'CHALLENGER',
#    'masteries': [{'masteryId': 4111, 'rank': 1},
#     {'masteryId': 4113, 'rank': 2},
#     {'masteryId': 4114, 'rank': 1},
#     {'masteryId': 4121, 'rank': 1},
#     {'masteryId': 4122, 'rank': 3},
#     {'masteryId': 4124, 'rank': 1},
#     {'masteryId': 4131, 'rank': 1},
#     {'masteryId': 4132, 'rank': 1},
#     {'masteryId': 4134, 'rank': 3},
#     {'masteryId': 4141, 'rank': 1},
#     {'masteryId': 4142, 'rank': 1},
#     {'masteryId': 4144, 'rank': 1},
#     {'masteryId': 4152, 'rank': 3},
#     {'masteryId': 4162, 'rank': 1},
#     {'masteryId': 4211, 'rank': 2},
#     {'masteryId': 4214, 'rank': 2},
#     {'masteryId': 4221, 'rank': 1},
#     {'masteryId': 4222, 'rank': 3},
#     {'masteryId': 4232, 'rank': 1}],
#    'participantId': 1,
#    'runes': [{'rank': 1, 'runeId': 5251},
#     {'rank': 8, 'runeId': 5253},
#     {'rank': 9, 'runeId': 5295},
#     {'rank': 9, 'runeId': 5317},
#     {'rank': 3, 'runeId': 5335}],
#    'spell1Id': 11,
#    'spell2Id': 4,
#    'stats': {'assists': 10,
#     'champLevel': 16,
#     'combatPlayerScore': 0,
#     'deaths': 6,
#     'doubleKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstInhibitorAssist': False,
#     'firstInhibitorKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'goldEarned': 12122,
#     'goldSpent': 11060,
#     'inhibitorKills': 0,
#     'item0': 3707,
#     'item1': 3155,
#     'item2': 3190,
#     'item3': 3111,
#     'item4': 3742,
#     'item5': 0,
#     'item6': 3341,
#     'killingSprees': 0,
#     'kills': 5,
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'magicDamageDealt': 12484,
#     'magicDamageDealtToChampions': 60,
#     'magicDamageTaken': 6711,
#     'minionsKilled': 30,
#     'neutralMinionsKilled': 74,
#     'neutralMinionsKilledEnemyJungle': 7,
#     'neutralMinionsKilledTeamJungle': 67,
#     'objectivePlayerScore': 0,
#     'pentaKills': 0,
#     'physicalDamageDealt': 120006,
#     'physicalDamageDealtToChampions': 11830,
#     'physicalDamageTaken': 17916,
#     'quadraKills': 0,
#     'sightWardsBoughtInGame': 2,
#     'totalDamageDealt': 145163,
#     'totalDamageDealtToChampions': 13320,
#     'totalDamageTaken': 25779,
#     'totalHeal': 4429,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'totalTimeCrowdControlDealt': 208,
#     'totalUnitsHealed': 1,
#     'towerKills': 0,
#     'tripleKills': 0,
#     'trueDamageDealt': 12672,
#     'trueDamageDealtToChampions': 1429,
#     'trueDamageTaken': 1151,
#     'unrealKills': 0,
#     'visionWardsBoughtInGame': 3,
#     'wardsKilled': 6,
#     'wardsPlaced': 7,
#     'winner': True},
#    'teamId': 100,
#    'timeline': {'creepsPerMinDeltas': {'tenToTwenty': 1.7,
#      'thirtyToEnd': 0.8,
#      'twentyToThirty': 0.7,
#      'zeroToTen': 0.1},
#     'csDiffPerMinDeltas': {'tenToTwenty': -2.0,
#      'thirtyToEnd': -8.2,
#      'twentyToThirty': -1.9,
#      'zeroToTen': -1.2999999999999998},
#     'damageTakenDiffPerMinDeltas': {'tenToTwenty': -39.19999999999999,
#      'thirtyToEnd': 437.4000000000001,
#      'twentyToThirty': -770.3000000000001,
#      'zeroToTen': -405.5},
#     'damageTakenPerMinDeltas': {'tenToTwenty': 578.7,
#      'thirtyToEnd': 1024.4,
#      'twentyToThirty': 1004.9,
#      'zeroToTen': 409.7},
#     'goldPerMinDeltas': {'tenToTwenty': 289.7,
#      'thirtyToEnd': 410.6,
#      'twentyToThirty': 356.9,
#      'zeroToTen': 258.3},
#     'lane': 'JUNGLE',
#     'role': 'NONE',
#     'xpDiffPerMinDeltas': {'tenToTwenty': -120.60000000000002,
#      'thirtyToEnd': -152.20000000000005,
#      'twentyToThirty': 93.49999999999997,
#      'zeroToTen': -103.20000000000002},
#     'xpPerMinDeltas': {'tenToTwenty': 366.5,
#      'thirtyToEnd': 600.4,
#      'twentyToThirty': 486.7,
#      'zeroToTen': 293.79999999999995}}},
#   {'championId': 131,
#    'highestAchievedSeasonTier': 'MASTER',
#    'masteries': [{'masteryId': 4111, 'rank': 1},
#     {'masteryId': 4113, 'rank': 4},
#     {'masteryId': 4123, 'rank': 3},
#     {'masteryId': 4133, 'rank': 1},
#     {'masteryId': 4134, 'rank': 3},
#     {'masteryId': 4143, 'rank': 3},
#     {'masteryId': 4144, 'rank': 1},
#     {'masteryId': 4152, 'rank': 3},
#     {'masteryId': 4154, 'rank': 1},
#     {'masteryId': 4162, 'rank': 1},
#     {'masteryId': 4211, 'rank': 2},
#     {'masteryId': 4212, 'rank': 2},
#     {'masteryId': 4221, 'rank': 1},
#     {'masteryId': 4222, 'rank': 3},
#     {'masteryId': 4232, 'rank': 1}],
#    'participantId': 2,
#    'runes': [{'rank': 9, 'runeId': 5273},
#     {'rank': 9, 'runeId': 5296},
#     {'rank': 9, 'runeId': 5316},
#     {'rank': 3, 'runeId': 5357}],
#    'spell1Id': 12,
#    'spell2Id': 4,
#    'stats': {'assists': 9,
#     'champLevel': 17,
#     'combatPlayerScore': 0,
#     'deaths': 7,
#     'doubleKills': 1,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstInhibitorAssist': False,
#     'firstInhibitorKill': True,
#     'firstTowerAssist': False,
#     'firstTowerKill': True,
#     'goldEarned': 14227,
#     'goldSpent': 12990,
#     'inhibitorKills': 1,
#     'item0': 1056,
#     'item1': 3157,
#     'item2': 1026,
#     'item3': 3115,
#     'item4': 3001,
#     'item5': 1324,
#     'item6': 3361,
#     'killingSprees': 2,
#     'kills': 6,
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 2,
#     'magicDamageDealt': 191348,
#     'magicDamageDealtToChampions': 24513,
#     'magicDamageTaken': 11793,
#     'minionsKilled': 219,
#     'neutralMinionsKilled': 31,
#     'neutralMinionsKilledEnemyJungle': 3,
#     'neutralMinionsKilledTeamJungle': 28,
#     'objectivePlayerScore': 0,
#     'pentaKills': 0,
#     'physicalDamageDealt': 23286,
#     'physicalDamageDealtToChampions': 2448,
#     'physicalDamageTaken': 9517,
#     'quadraKills': 0,
#     'sightWardsBoughtInGame': 1,
#     'totalDamageDealt': 214966,
#     'totalDamageDealtToChampions': 27294,
#     'totalDamageTaken': 23456,
#     'totalHeal': 3116,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'totalTimeCrowdControlDealt': 136,
#     'totalUnitsHealed': 1,
#     'towerKills': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 332,
#     'trueDamageDealtToChampions': 332,
#     'trueDamageTaken': 2145,
#     'unrealKills': 0,
#     'visionWardsBoughtInGame': 3,
#     'wardsKilled': 3,
#     'wardsPlaced': 8,
#     'winner': True},
#    'teamId': 100,
#    'timeline': {'creepsPerMinDeltas': {'tenToTwenty': 6.5,
#      'thirtyToEnd': 8.0,
#      'twentyToThirty': 5.0,
#      'zeroToTen': 6.4},
#     'csDiffPerMinDeltas': {'tenToTwenty': -0.6000000000000001,
#      'thirtyToEnd': 1.2000000000000002,
#      'twentyToThirty': 2.4,
#      'zeroToTen': 1.3000000000000003},
#     'damageTakenDiffPerMinDeltas': {'tenToTwenty': -68.50000000000001,
#      'thirtyToEnd': 509.4,
#      'twentyToThirty': -293.70000000000005,
#      'zeroToTen': 97.0},
#     'damageTakenPerMinDeltas': {'tenToTwenty': 339.5,
#      'thirtyToEnd': 1082.8,
#      'twentyToThirty': 703.7,
#      'zeroToTen': 514.7},
#     'goldPerMinDeltas': {'tenToTwenty': 305.70000000000005,
#      'thirtyToEnd': 481.2,
#      'twentyToThirty': 543.0999999999999,
#      'zeroToTen': 259.5},
#     'lane': 'MIDDLE',
#     'role': 'SOLO',
#     'xpDiffPerMinDeltas': {'tenToTwenty': 2.3000000000000114,
#      'thirtyToEnd': 180.60000000000002,
#      'twentyToThirty': 385.0,
#      'zeroToTen': 18.899999999999977},
#     'xpPerMinDeltas': {'tenToTwenty': 409.1,
#      'thirtyToEnd': 658.2,
#      'twentyToThirty': 686.2,
#      'zeroToTen': 391.4}}},
#   {'championId': 63,
#    'highestAchievedSeasonTier': 'DIAMOND',
#    'masteries': [{'masteryId': 4113, 'rank': 4},
#     {'masteryId': 4121, 'rank': 1},
#     {'masteryId': 4123, 'rank': 3},
#     {'masteryId': 4131, 'rank': 1},
#     {'masteryId': 4133, 'rank': 1},
#     {'masteryId': 4134, 'rank': 3},
#     {'masteryId': 4143, 'rank': 3},
#     {'masteryId': 4144, 'rank': 1},
#     {'masteryId': 4152, 'rank': 3},
#     {'masteryId': 4162, 'rank': 1},
#     {'masteryId': 4211, 'rank': 2},
#     {'masteryId': 4212, 'rank': 2},
#     {'masteryId': 4221, 'rank': 1},
#     {'masteryId': 4222, 'rank': 3},
#     {'masteryId': 4232, 'rank': 1}],
#    'participantId': 3,
#    'runes': [{'rank': 9, 'runeId': 5273},
#     {'rank': 9, 'runeId': 5297},
#     {'rank': 9, 'runeId': 5317},
#     {'rank': 3, 'runeId': 5357}],
#    'spell1Id': 4,
#    'spell2Id': 14,
#    'stats': {'assists': 18,
#     'champLevel': 16,
#     'combatPlayerScore': 0,
#     'deaths': 3,
#     'doubleKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstInhibitorAssist': True,
#     'firstInhibitorKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'goldEarned': 12437,
#     'goldSpent': 10610,
#     'inhibitorKills': 1,
#     'item0': 3092,
#     'item1': 2049,
#     'item2': 3050,
#     'item3': 1028,
#     'item4': 3151,
#     'item5': 3117,
#     'item6': 3341,
#     'killingSprees': 1,
#     'kills': 5,
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'magicDamageDealt': 49661,
#     'magicDamageDealtToChampions': 27303,
#     'magicDamageTaken': 9407,
#     'minionsKilled': 30,
#     'neutralMinionsKilled': 0,
#     'neutralMinionsKilledEnemyJungle': 0,
#     'neutralMinionsKilledTeamJungle': 0,
#     'objectivePlayerScore': 0,
#     'pentaKills': 0,
#     'physicalDamageDealt': 7153,
#     'physicalDamageDealtToChampions': 1187,
#     'physicalDamageTaken': 5945,
#     'quadraKills': 0,
#     'sightWardsBoughtInGame': 2,
#     'totalDamageDealt': 57135,
#     'totalDamageDealtToChampions': 28810,
#     'totalDamageTaken': 16315,
#     'totalHeal': 2037,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'totalTimeCrowdControlDealt': 77,
#     'totalUnitsHealed': 1,
#     'towerKills': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 320,
#     'trueDamageDealtToChampions': 320,
#     'trueDamageTaken': 963,
#     'unrealKills': 0,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 4,
#     'wardsPlaced': 24,
#     'winner': True},
#    'teamId': 100,
#    'timeline': {'creepsPerMinDeltas': {'tenToTwenty': 1.3,
#      'thirtyToEnd': 0.8,
#      'twentyToThirty': 1.1,
#      'zeroToTen': 0.1},
#     'csDiffPerMinDeltas': {'tenToTwenty': -1.6000000000000003,
#      'thirtyToEnd': 2.6,
#      'twentyToThirty': -0.19999999999999996,
#      'zeroToTen': 1.3499999999999999},
#     'damageTakenDiffPerMinDeltas': {'tenToTwenty': -73.25,
#      'thirtyToEnd': -617.6999999999998,
#      'twentyToThirty': -280.05000000000007,
#      'zeroToTen': -220.35000000000002},
#     'damageTakenPerMinDeltas': {'tenToTwenty': 230.5,
#      'thirtyToEnd': 1100.4,
#      'twentyToThirty': 620.9,
#      'zeroToTen': 207.5},
#     'goldPerMinDeltas': {'tenToTwenty': 293.2,
#      'thirtyToEnd': 321.2,
#      'twentyToThirty': 398.2,
#      'zeroToTen': 224.39999999999998},
#     'lane': 'BOTTOM',
#     'role': 'DUO_SUPPORT',
#     'xpDiffPerMinDeltas': {'tenToTwenty': -108.84999999999997,
#      'thirtyToEnd': 42.600000000000136,
#      'twentyToThirty': 31.44999999999999,
#      'zeroToTen': 47.94999999999999},
#     'xpPerMinDeltas': {'tenToTwenty': 334.9,
#      'thirtyToEnd': 510.6,
#      'twentyToThirty': 452.7,
#      'zeroToTen': 306.5}}},
#   {'championId': 59,
#    'highestAchievedSeasonTier': 'CHALLENGER',
#    'masteries': [{'masteryId': 4112, 'rank': 1},
#     {'masteryId': 4113, 'rank': 4},
#     {'masteryId': 4114, 'rank': 1},
#     {'masteryId': 4122, 'rank': 3},
#     {'masteryId': 4124, 'rank': 1},
#     {'masteryId': 4131, 'rank': 1},
#     {'masteryId': 4132, 'rank': 1},
#     {'masteryId': 4134, 'rank': 3},
#     {'masteryId': 4141, 'rank': 1},
#     {'masteryId': 4144, 'rank': 1},
#     {'masteryId': 4152, 'rank': 3},
#     {'masteryId': 4162, 'rank': 1},
#     {'masteryId': 4211, 'rank': 2},
#     {'masteryId': 4212, 'rank': 2},
#     {'masteryId': 4221, 'rank': 1},
#     {'masteryId': 4222, 'rank': 3},
#     {'masteryId': 4232, 'rank': 1}],
#    'participantId': 4,
#    'runes': [{'rank': 9, 'runeId': 5245},
#     {'rank': 3, 'runeId': 5289},
#     {'rank': 6, 'runeId': 5295},
#     {'rank': 9, 'runeId': 5317},
#     {'rank': 3, 'runeId': 5335}],
#    'spell1Id': 12,
#    'spell2Id': 4,
#    'stats': {'assists': 14,
#     'champLevel': 18,
#     'combatPlayerScore': 0,
#     'deaths': 3,
#     'doubleKills': 2,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstInhibitorAssist': True,
#     'firstInhibitorKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'goldEarned': 17208,
#     'goldSpent': 15290,
#     'inhibitorKills': 0,
#     'item0': 1324,
#     'item1': 3074,
#     'item2': 1031,
#     'item3': 3156,
#     'item4': 3102,
#     'item5': 3035,
#     'item6': 3361,
#     'killingSprees': 4,
#     'kills': 12,
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 2,
#     'magicDamageDealt': 9328,
#     'magicDamageDealtToChampions': 2375,
#     'magicDamageTaken': 9243,
#     'minionsKilled': 275,
#     'neutralMinionsKilled': 11,
#     'neutralMinionsKilledEnemyJungle': 2,
#     'neutralMinionsKilledTeamJungle': 9,
#     'objectivePlayerScore': 0,
#     'pentaKills': 0,
#     'physicalDamageDealt': 222652,
#     'physicalDamageDealtToChampions': 32630,
#     'physicalDamageTaken': 18255,
#     'quadraKills': 0,
#     'sightWardsBoughtInGame': 4,
#     'totalDamageDealt': 231981,
#     'totalDamageDealtToChampions': 35005,
#     'totalDamageTaken': 31239,
#     'totalHeal': 8199,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'totalTimeCrowdControlDealt': 235,
#     'totalUnitsHealed': 1,
#     'towerKills': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 0,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 3739,
#     'unrealKills': 0,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 2,
#     'wardsPlaced': 24,
#     'winner': True},
#    'teamId': 100,
#    'timeline': {'creepsPerMinDeltas': {'tenToTwenty': 8.3,
#      'thirtyToEnd': 5.6,
#      'twentyToThirty': 9.3,
#      'zeroToTen': 6.199999999999999},
#     'csDiffPerMinDeltas': {'tenToTwenty': 2.5,
#      'thirtyToEnd': 1.1999999999999993,
#      'twentyToThirty': 3.4,
#      'zeroToTen': 2.5999999999999996},
#     'damageTakenDiffPerMinDeltas': {'tenToTwenty': -184.39999999999998,
#      'thirtyToEnd': 230.39999999999998,
#      'twentyToThirty': -212.90000000000003,
#      'zeroToTen': -162.20000000000002},
#     'damageTakenPerMinDeltas': {'tenToTwenty': 721.4000000000001,
#      'thirtyToEnd': 1030.0,
#      'twentyToThirty': 1202.0,
#      'zeroToTen': 418.2},
#     'goldPerMinDeltas': {'tenToTwenty': 499.1,
#      'thirtyToEnd': 424.2,
#      'twentyToThirty': 519.4,
#      'zeroToTen': 330.5},
#     'lane': 'TOP',
#     'role': 'SOLO',
#     'xpDiffPerMinDeltas': {'tenToTwenty': 244.49999999999997,
#      'thirtyToEnd': 188.20000000000005,
#      'twentyToThirty': 347.20000000000005,
#      'zeroToTen': 21.600000000000023},
#     'xpPerMinDeltas': {'tenToTwenty': 610.9,
#      'thirtyToEnd': 728.2,
#      'twentyToThirty': 697.5,
#      'zeroToTen': 397.70000000000005}}},
#   {'championId': 429,
#    'highestAchievedSeasonTier': 'DIAMOND',
#    'masteries': [{'masteryId': 4112, 'rank': 4},
#     {'masteryId': 4114, 'rank': 1},
#     {'masteryId': 4122, 'rank': 3},
#     {'masteryId': 4124, 'rank': 1},
#     {'masteryId': 4131, 'rank': 1},
#     {'masteryId': 4132, 'rank': 1},
#     {'masteryId': 4134, 'rank': 3},
#     {'masteryId': 4141, 'rank': 1},
#     {'masteryId': 4142, 'rank': 3},
#     {'masteryId': 4144, 'rank': 1},
#     {'masteryId': 4152, 'rank': 1},
#     {'masteryId': 4162, 'rank': 1},
#     {'masteryId': 4211, 'rank': 2},
#     {'masteryId': 4212, 'rank': 2},
#     {'masteryId': 4221, 'rank': 1},
#     {'masteryId': 4222, 'rank': 3},
#     {'masteryId': 4232, 'rank': 1}],
#    'participantId': 5,
#    'runes': [{'rank': 9, 'runeId': 5245},
#     {'rank': 9, 'runeId': 5289},
#     {'rank': 9, 'runeId': 5317},
#     {'rank': 3, 'runeId': 5337}],
#    'spell1Id': 7,
#    'spell2Id': 4,
#    'stats': {'assists': 13,
#     'champLevel': 17,
#     'combatPlayerScore': 0,
#     'deaths': 4,
#     'doubleKills': 3,
#     'firstBloodAssist': False,
#     'firstBloodKill': True,
#     'firstInhibitorAssist': True,
#     'firstInhibitorKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'goldEarned': 16173,
#     'goldSpent': 13673,
#     'inhibitorKills': 1,
#     'item0': 3153,
#     'item1': 3139,
#     'item2': 0,
#     'item3': 3035,
#     'item4': 3006,
#     'item5': 3085,
#     'item6': 3342,
#     'killingSprees': 2,
#     'kills': 10,
#     'largestCriticalStrike': 709,
#     'largestKillingSpree': 7,
#     'largestMultiKill': 2,
#     'magicDamageDealt': 3304,
#     'magicDamageDealtToChampions': 1457,
#     'magicDamageTaken': 7126,
#     'minionsKilled': 228,
#     'neutralMinionsKilled': 13,
#     'neutralMinionsKilledEnemyJungle': 9,
#     'neutralMinionsKilledTeamJungle': 4,
#     'objectivePlayerScore': 0,
#     'pentaKills': 0,
#     'physicalDamageDealt': 198671,
#     'physicalDamageDealtToChampions': 25147,
#     'physicalDamageTaken': 7948,
#     'quadraKills': 0,
#     'sightWardsBoughtInGame': 0,
#     'totalDamageDealt': 204139,
#     'totalDamageDealtToChampions': 27134,
#     'totalDamageTaken': 16228,
#     'totalHeal': 4500,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'totalTimeCrowdControlDealt': 717,
#     'totalUnitsHealed': 4,
#     'towerKills': 6,
#     'tripleKills': 0,
#     'trueDamageDealt': 2163,
#     'trueDamageDealtToChampions': 529,
#     'trueDamageTaken': 1152,
#     'unrealKills': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 3,
#     'wardsPlaced': 1,
#     'winner': True},
#    'teamId': 100,
#    'timeline': {'creepsPerMinDeltas': {'tenToTwenty': 5.3,
#      'thirtyToEnd': 10.2,
#      'twentyToThirty': 4.8,
#      'zeroToTen': 6.3},
#     'csDiffPerMinDeltas': {'tenToTwenty': -1.6000000000000003,
#      'thirtyToEnd': 2.6,
#      'twentyToThirty': -0.19999999999999996,
#      'zeroToTen': 1.3499999999999999},
#     'damageTakenDiffPerMinDeltas': {'tenToTwenty': -73.25,
#      'thirtyToEnd': -617.6999999999998,
#      'twentyToThirty': -280.05000000000007,
#      'zeroToTen': -220.35000000000002},
#     'damageTakenPerMinDeltas': {'tenToTwenty': 315.0,
#      'thirtyToEnd': 303.4,
#      'twentyToThirty': 744.5,
#      'zeroToTen': 241.39999999999998},
#     'goldPerMinDeltas': {'tenToTwenty': 296.1,
#      'thirtyToEnd': 513.4,
#      'twentyToThirty': 556.5,
#      'zeroToTen': 326.5},
#     'lane': 'BOTTOM',
#     'role': 'DUO_CARRY',
#     'xpDiffPerMinDeltas': {'tenToTwenty': -108.84999999999997,
#      'thirtyToEnd': 42.600000000000136,
#      'twentyToThirty': 31.44999999999999,
#      'zeroToTen': 47.94999999999999},
#     'xpPerMinDeltas': {'tenToTwenty': 340.8,
#      'thirtyToEnd': 735.2,
#      'twentyToThirty': 579.2,
#      'zeroToTen': 310.4}}},
#   {'championId': 82,
#    'highestAchievedSeasonTier': 'DIAMOND',
#    'masteries': [{'masteryId': 4112, 'rank': 4},
#     {'masteryId': 4114, 'rank': 1},
#     {'masteryId': 4122, 'rank': 3},
#     {'masteryId': 4124, 'rank': 1},
#     {'masteryId': 4131, 'rank': 1},
#     {'masteryId': 4132, 'rank': 1},
#     {'masteryId': 4134, 'rank': 3},
#     {'masteryId': 4141, 'rank': 1},
#     {'masteryId': 4144, 'rank': 1},
#     {'masteryId': 4151, 'rank': 1},
#     {'masteryId': 4152, 'rank': 3},
#     {'masteryId': 4162, 'rank': 1},
#     {'masteryId': 4211, 'rank': 2},
#     {'masteryId': 4212, 'rank': 2},
#     {'masteryId': 4221, 'rank': 1},
#     {'masteryId': 4222, 'rank': 3},
#     {'masteryId': 4232, 'rank': 1}],
#    'participantId': 6,
#    'runes': [{'rank': 9, 'runeId': 5245},
#     {'rank': 9, 'runeId': 5289},
#     {'rank': 9, 'runeId': 5317},
#     {'rank': 3, 'runeId': 5337}],
#    'spell1Id': 3,
#    'spell2Id': 4,
#    'stats': {'assists': 7,
#     'champLevel': 18,
#     'combatPlayerScore': 0,
#     'deaths': 8,
#     'doubleKills': 2,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstInhibitorAssist': False,
#     'firstInhibitorKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'goldEarned': 13793,
#     'goldSpent': 13148,
#     'inhibitorKills': 0,
#     'item0': 3302,
#     'item1': 3116,
#     'item2': 1026,
#     'item3': 3078,
#     'item4': 1319,
#     'item5': 3151,
#     'item6': 3340,
#     'killingSprees': 2,
#     'kills': 6,
#     'largestCriticalStrike': 680,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 3,
#     'magicDamageDealt': 169698,
#     'magicDamageDealtToChampions': 13502,
#     'magicDamageTaken': 8920,
#     'minionsKilled': 200,
#     'neutralMinionsKilled': 56,
#     'neutralMinionsKilledEnemyJungle': 2,
#     'neutralMinionsKilledTeamJungle': 54,
#     'objectivePlayerScore': 0,
#     'pentaKills': 0,
#     'physicalDamageDealt': 85164,
#     'physicalDamageDealtToChampions': 5657,
#     'physicalDamageTaken': 13888,
#     'quadraKills': 0,
#     'sightWardsBoughtInGame': 0,
#     'totalDamageDealt': 257780,
#     'totalDamageDealtToChampions': 19247,
#     'totalDamageTaken': 23079,
#     'totalHeal': 13131,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'totalTimeCrowdControlDealt': 411,
#     'totalUnitsHealed': 6,
#     'towerKills': 1,
#     'tripleKills': 1,
#     'trueDamageDealt': 2917,
#     'trueDamageDealtToChampions': 88,
#     'trueDamageTaken': 270,
#     'unrealKills': 0,
#     'visionWardsBoughtInGame': 3,
#     'wardsKilled': 4,
#     'wardsPlaced': 13,
#     'winner': False},
#    'teamId': 200,
#    'timeline': {'creepsPerMinDeltas': {'tenToTwenty': 8.5,
#      'thirtyToEnd': 4.8,
#      'twentyToThirty': 5.6,
#      'zeroToTen': 2.9},
#     'csDiffPerMinDeltas': {'tenToTwenty': 1.6000000000000003,
#      'thirtyToEnd': -2.6,
#      'twentyToThirty': 0.19999999999999996,
#      'zeroToTen': -1.3499999999999999},
#     'damageTakenDiffPerMinDeltas': {'tenToTwenty': 73.25,
#      'thirtyToEnd': 617.6999999999998,
#      'twentyToThirty': 280.05000000000007,
#      'zeroToTen': 220.35000000000002},
#     'damageTakenPerMinDeltas': {'tenToTwenty': 221.60000000000002,
#      'thirtyToEnd': 1154.4,
#      'twentyToThirty': 628.0,
#      'zeroToTen': 410.4},
#     'goldPerMinDeltas': {'tenToTwenty': 414.1,
#      'thirtyToEnd': 409.4,
#      'twentyToThirty': 487.09999999999997,
#      'zeroToTen': 193.89999999999998},
#     'lane': 'BOTTOM',
#     'role': 'DUO_CARRY',
#     'xpDiffPerMinDeltas': {'tenToTwenty': 108.84999999999997,
#      'thirtyToEnd': -42.600000000000136,
#      'twentyToThirty': -31.44999999999999,
#      'zeroToTen': -47.94999999999999},
#     'xpPerMinDeltas': {'tenToTwenty': 632.8,
#      'thirtyToEnd': 652.8,
#      'twentyToThirty': 640.3,
#      'zeroToTen': 277.0}}},
#   {'championId': 1,
#    'highestAchievedSeasonTier': 'DIAMOND',
#    'masteries': [{'masteryId': 4113, 'rank': 3},
#     {'masteryId': 4114, 'rank': 1},
#     {'masteryId': 4121, 'rank': 1},
#     {'masteryId': 4123, 'rank': 3},
#     {'masteryId': 4124, 'rank': 1},
#     {'masteryId': 4133, 'rank': 1},
#     {'masteryId': 4134, 'rank': 3},
#     {'masteryId': 4143, 'rank': 3},
#     {'masteryId': 4144, 'rank': 1},
#     {'masteryId': 4152, 'rank': 2},
#     {'masteryId': 4154, 'rank': 1},
#     {'masteryId': 4162, 'rank': 1},
#     {'masteryId': 4311, 'rank': 1},
#     {'masteryId': 4312, 'rank': 3},
#     {'masteryId': 4322, 'rank': 3},
#     {'masteryId': 4324, 'rank': 1},
#     {'masteryId': 4334, 'rank': 1}],
#    'participantId': 7,
#    'runes': [{'rank': 9, 'runeId': 5273},
#     {'rank': 9, 'runeId': 5303},
#     {'rank': 9, 'runeId': 5316},
#     {'rank': 3, 'runeId': 5363}],
#    'spell1Id': 4,
#    'spell2Id': 14,
#    'stats': {'assists': 7,
#     'champLevel': 15,
#     'combatPlayerScore': 0,
#     'deaths': 7,
#     'doubleKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstInhibitorAssist': False,
#     'firstInhibitorKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'goldEarned': 10783,
#     'goldSpent': 10765,
#     'inhibitorKills': 0,
#     'item0': 2041,
#     'item1': 3135,
#     'item2': 3001,
#     'item3': 1313,
#     'item4': 1058,
#     'item5': 3136,
#     'item6': 3362,
#     'killingSprees': 1,
#     'kills': 4,
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'magicDamageDealt': 86156,
#     'magicDamageDealtToChampions': 16746,
#     'magicDamageTaken': 9758,
#     'minionsKilled': 182,
#     'neutralMinionsKilled': 0,
#     'neutralMinionsKilledEnemyJungle': 0,
#     'neutralMinionsKilledTeamJungle': 0,
#     'objectivePlayerScore': 0,
#     'pentaKills': 0,
#     'physicalDamageDealt': 14677,
#     'physicalDamageDealtToChampions': 2226,
#     'physicalDamageTaken': 13246,
#     'quadraKills': 0,
#     'sightWardsBoughtInGame': 0,
#     'totalDamageDealt': 101722,
#     'totalDamageDealtToChampions': 19861,
#     'totalDamageTaken': 23211,
#     'totalHeal': 876,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'totalTimeCrowdControlDealt': 107,
#     'totalUnitsHealed': 1,
#     'towerKills': 0,
#     'tripleKills': 0,
#     'trueDamageDealt': 889,
#     'trueDamageDealtToChampions': 889,
#     'trueDamageTaken': 206,
#     'unrealKills': 0,
#     'visionWardsBoughtInGame': 2,
#     'wardsKilled': 7,
#     'wardsPlaced': 14,
#     'winner': False},
#    'teamId': 200,
#    'timeline': {'creepsPerMinDeltas': {'tenToTwenty': 7.1,
#      'thirtyToEnd': 6.8,
#      'twentyToThirty': 2.5999999999999996,
#      'zeroToTen': 5.1},
#     'csDiffPerMinDeltas': {'tenToTwenty': 0.6000000000000001,
#      'thirtyToEnd': -1.2000000000000002,
#      'twentyToThirty': -2.4,
#      'zeroToTen': -1.3000000000000003},
#     'damageTakenDiffPerMinDeltas': {'tenToTwenty': 68.50000000000001,
#      'thirtyToEnd': -509.4,
#      'twentyToThirty': 293.70000000000005,
#      'zeroToTen': -97.0},
#     'damageTakenPerMinDeltas': {'tenToTwenty': 408.0,
#      'thirtyToEnd': 573.4,
#      'twentyToThirty': 997.4000000000001,
#      'zeroToTen': 417.7},
#     'goldPerMinDeltas': {'tenToTwenty': 330.9,
#      'thirtyToEnd': 351.4,
#      'twentyToThirty': 272.7,
#      'zeroToTen': 240.2},
#     'lane': 'MIDDLE',
#     'role': 'SOLO',
#     'xpDiffPerMinDeltas': {'tenToTwenty': -2.3000000000000114,
#      'thirtyToEnd': -180.60000000000002,
#      'twentyToThirty': -385.0,
#      'zeroToTen': -18.899999999999977},
#     'xpPerMinDeltas': {'tenToTwenty': 406.79999999999995,
#      'thirtyToEnd': 477.6,
#      'twentyToThirty': 301.2,
#      'zeroToTen': 372.5}}},
#   {'championId': 2,
#    'highestAchievedSeasonTier': 'DIAMOND',
#    'masteries': [{'masteryId': 4111, 'rank': 1},
#     {'masteryId': 4112, 'rank': 3},
#     {'masteryId': 4114, 'rank': 1},
#     {'masteryId': 4122, 'rank': 3},
#     {'masteryId': 4131, 'rank': 1},
#     {'masteryId': 4132, 'rank': 1},
#     {'masteryId': 4134, 'rank': 3},
#     {'masteryId': 4141, 'rank': 1},
#     {'masteryId': 4142, 'rank': 2},
#     {'masteryId': 4144, 'rank': 1},
#     {'masteryId': 4152, 'rank': 3},
#     {'masteryId': 4162, 'rank': 1},
#     {'masteryId': 4211, 'rank': 2},
#     {'masteryId': 4214, 'rank': 2},
#     {'masteryId': 4221, 'rank': 1},
#     {'masteryId': 4222, 'rank': 3},
#     {'masteryId': 4232, 'rank': 1}],
#    'participantId': 8,
#    'runes': [{'rank': 9, 'runeId': 5245},
#     {'rank': 3, 'runeId': 5290},
#     {'rank': 6, 'runeId': 5295},
#     {'rank': 9, 'runeId': 5317},
#     {'rank': 3, 'runeId': 5337}],
#    'spell1Id': 11,
#    'spell2Id': 4,
#    'stats': {'assists': 7,
#     'champLevel': 17,
#     'combatPlayerScore': 0,
#     'deaths': 7,
#     'doubleKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstInhibitorAssist': False,
#     'firstInhibitorKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'goldEarned': 14193,
#     'goldSpent': 13835,
#     'inhibitorKills': 0,
#     'item0': 3725,
#     'item1': 3742,
#     'item2': 3047,
#     'item3': 3071,
#     'item4': 3065,
#     'item5': 3082,
#     'item6': 3361,
#     'killingSprees': 1,
#     'kills': 6,
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 1,
#     'magicDamageDealt': 29167,
#     'magicDamageDealtToChampions': 1125,
#     'magicDamageTaken': 13322,
#     'minionsKilled': 123,
#     'neutralMinionsKilled': 93,
#     'neutralMinionsKilledEnemyJungle': 2,
#     'neutralMinionsKilledTeamJungle': 91,
#     'objectivePlayerScore': 0,
#     'pentaKills': 0,
#     'physicalDamageDealt': 148094,
#     'physicalDamageDealtToChampions': 7747,
#     'physicalDamageTaken': 26153,
#     'quadraKills': 0,
#     'sightWardsBoughtInGame': 0,
#     'totalDamageDealt': 223253,
#     'totalDamageDealtToChampions': 13826,
#     'totalDamageTaken': 40168,
#     'totalHeal': 5676,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'totalTimeCrowdControlDealt': 1121,
#     'totalUnitsHealed': 1,
#     'towerKills': 0,
#     'tripleKills': 0,
#     'trueDamageDealt': 45992,
#     'trueDamageDealtToChampions': 4953,
#     'trueDamageTaken': 692,
#     'unrealKills': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 7,
#     'wardsPlaced': 21,
#     'winner': False},
#    'teamId': 200,
#    'timeline': {'creepsPerMinDeltas': {'tenToTwenty': 3.7,
#      'thirtyToEnd': 9.0,
#      'twentyToThirty': 2.5999999999999996,
#      'zeroToTen': 1.4},
#     'csDiffPerMinDeltas': {'tenToTwenty': 2.0,
#      'thirtyToEnd': 8.2,
#      'twentyToThirty': 1.9,
#      'zeroToTen': 1.2999999999999998},
#     'damageTakenDiffPerMinDeltas': {'tenToTwenty': 39.19999999999999,
#      'thirtyToEnd': -437.4000000000001,
#      'twentyToThirty': 770.3000000000001,
#      'zeroToTen': 405.5},
#     'damageTakenPerMinDeltas': {'tenToTwenty': 617.9,
#      'thirtyToEnd': 587.0,
#      'twentyToThirty': 1775.2,
#      'zeroToTen': 815.2},
#     'goldPerMinDeltas': {'tenToTwenty': 378.7,
#      'thirtyToEnd': 482.8,
#      'twentyToThirty': 420.4,
#      'zeroToTen': 288.1},
#     'lane': 'JUNGLE',
#     'role': 'NONE',
#     'xpDiffPerMinDeltas': {'tenToTwenty': 120.60000000000002,
#      'thirtyToEnd': 152.20000000000005,
#      'twentyToThirty': -93.49999999999997,
#      'zeroToTen': 103.20000000000002},
#     'xpPerMinDeltas': {'tenToTwenty': 487.1,
#      'thirtyToEnd': 752.6,
#      'twentyToThirty': 393.20000000000005,
#      'zeroToTen': 397.0}}},
#   {'championId': 86,
#    'highestAchievedSeasonTier': 'DIAMOND',
#    'masteries': [{'masteryId': 4111, 'rank': 1},
#     {'masteryId': 4113, 'rank': 3},
#     {'masteryId': 4114, 'rank': 1},
#     {'masteryId': 4122, 'rank': 3},
#     {'masteryId': 4124, 'rank': 1},
#     {'masteryId': 4131, 'rank': 1},
#     {'masteryId': 4132, 'rank': 1},
#     {'masteryId': 4134, 'rank': 3},
#     {'masteryId': 4141, 'rank': 1},
#     {'masteryId': 4142, 'rank': 1},
#     {'masteryId': 4144, 'rank': 1},
#     {'masteryId': 4152, 'rank': 3},
#     {'masteryId': 4162, 'rank': 1},
#     {'masteryId': 4211, 'rank': 2},
#     {'masteryId': 4212, 'rank': 2},
#     {'masteryId': 4221, 'rank': 1},
#     {'masteryId': 4222, 'rank': 3},
#     {'masteryId': 4232, 'rank': 1}],
#    'participantId': 9,
#    'runes': [{'rank': 4, 'runeId': 5245},
#     {'rank': 5, 'runeId': 5253},
#     {'rank': 4, 'runeId': 5289},
#     {'rank': 5, 'runeId': 5295},
#     {'rank': 9, 'runeId': 5317},
#     {'rank': 3, 'runeId': 5335}],
#    'spell1Id': 4,
#    'spell2Id': 12,
#    'stats': {'assists': 3,
#     'champLevel': 15,
#     'combatPlayerScore': 0,
#     'deaths': 8,
#     'doubleKills': 1,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstInhibitorAssist': False,
#     'firstInhibitorKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'goldEarned': 11206,
#     'goldSpent': 10665,
#     'inhibitorKills': 0,
#     'item0': 3047,
#     'item1': 1054,
#     'item2': 3068,
#     'item3': 3742,
#     'item4': 3065,
#     'item5': 1011,
#     'item6': 3340,
#     'killingSprees': 2,
#     'kills': 6,
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 2,
#     'magicDamageDealt': 26193,
#     'magicDamageDealtToChampions': 3663,
#     'magicDamageTaken': 9301,
#     'minionsKilled': 178,
#     'neutralMinionsKilled': 8,
#     'neutralMinionsKilledEnemyJungle': 3,
#     'neutralMinionsKilledTeamJungle': 5,
#     'objectivePlayerScore': 0,
#     'pentaKills': 0,
#     'physicalDamageDealt': 98964,
#     'physicalDamageDealtToChampions': 13341,
#     'physicalDamageTaken': 26873,
#     'quadraKills': 0,
#     'sightWardsBoughtInGame': 0,
#     'totalDamageDealt': 128072,
#     'totalDamageDealtToChampions': 19919,
#     'totalDamageTaken': 37165,
#     'totalHeal': 608,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'totalTimeCrowdControlDealt': 118,
#     'totalUnitsHealed': 1,
#     'towerKills': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 2914,
#     'trueDamageDealtToChampions': 2914,
#     'trueDamageTaken': 990,
#     'unrealKills': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 3,
#     'wardsPlaced': 8,
#     'winner': False},
#    'teamId': 200,
#    'timeline': {'creepsPerMinDeltas': {'tenToTwenty': 5.8,
#      'thirtyToEnd': 4.4,
#      'twentyToThirty': 5.9,
#      'zeroToTen': 3.5999999999999996},
#     'csDiffPerMinDeltas': {'tenToTwenty': -2.5,
#      'thirtyToEnd': -1.1999999999999993,
#      'twentyToThirty': -3.4,
#      'zeroToTen': -2.5999999999999996},
#     'damageTakenDiffPerMinDeltas': {'tenToTwenty': 184.39999999999998,
#      'thirtyToEnd': -230.39999999999998,
#      'twentyToThirty': 212.90000000000003,
#      'zeroToTen': 162.20000000000002},
#     'damageTakenPerMinDeltas': {'tenToTwenty': 905.8,
#      'thirtyToEnd': 799.6,
#      'twentyToThirty': 1414.9,
#      'zeroToTen': 580.4},
#     'goldPerMinDeltas': {'tenToTwenty': 320.79999999999995,
#      'thirtyToEnd': 325.8,
#      'twentyToThirty': 293.4,
#      'zeroToTen': 275.79999999999995},
#     'lane': 'TOP',
#     'role': 'SOLO',
#     'xpDiffPerMinDeltas': {'tenToTwenty': -244.49999999999997,
#      'thirtyToEnd': -188.20000000000005,
#      'twentyToThirty': -347.20000000000005,
#      'zeroToTen': -21.600000000000023},
#     'xpPerMinDeltas': {'tenToTwenty': 366.4,
#      'thirtyToEnd': 540.0,
#      'twentyToThirty': 350.3,
#      'zeroToTen': 376.1}}},
#   {'championId': 201,
#    'highestAchievedSeasonTier': 'DIAMOND',
#    'masteries': [{'masteryId': 4211, 'rank': 2},
#     {'masteryId': 4212, 'rank': 2},
#     {'masteryId': 4221, 'rank': 1},
#     {'masteryId': 4222, 'rank': 3},
#     {'masteryId': 4232, 'rank': 1},
#     {'masteryId': 4311, 'rank': 1},
#     {'masteryId': 4312, 'rank': 3},
#     {'masteryId': 4322, 'rank': 3},
#     {'masteryId': 4324, 'rank': 1},
#     {'masteryId': 4331, 'rank': 3},
#     {'masteryId': 4334, 'rank': 1},
#     {'masteryId': 4341, 'rank': 1},
#     {'masteryId': 4342, 'rank': 1},
#     {'masteryId': 4343, 'rank': 3},
#     {'masteryId': 4353, 'rank': 3},
#     {'masteryId': 4362, 'rank': 1}],
#    'participantId': 10,
#    'runes': [{'rank': 9, 'runeId': 5257},
#     {'rank': 1, 'runeId': 5289},
#     {'rank': 2, 'runeId': 5290},
#     {'rank': 6, 'runeId': 5296},
#     {'rank': 9, 'runeId': 5316},
#     {'rank': 3, 'runeId': 5347}],
#    'spell1Id': 14,
#    'spell2Id': 4,
#    'stats': {'assists': 18,
#     'champLevel': 14,
#     'combatPlayerScore': 0,
#     'deaths': 8,
#     'doubleKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstInhibitorAssist': False,
#     'firstInhibitorKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'goldEarned': 9062,
#     'goldSpent': 8600,
#     'inhibitorKills': 0,
#     'item0': 1328,
#     'item1': 3105,
#     'item2': 3800,
#     'item3': 2049,
#     'item4': 1028,
#     'item5': 3097,
#     'item6': 3364,
#     'killingSprees': 0,
#     'kills': 1,
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'magicDamageDealt': 9449,
#     'magicDamageDealtToChampions': 7336,
#     'magicDamageTaken': 14407,
#     'minionsKilled': 33,
#     'neutralMinionsKilled': 0,
#     'neutralMinionsKilledEnemyJungle': 0,
#     'neutralMinionsKilledTeamJungle': 0,
#     'objectivePlayerScore': 0,
#     'pentaKills': 0,
#     'physicalDamageDealt': 5104,
#     'physicalDamageDealtToChampions': 1742,
#     'physicalDamageTaken': 19119,
#     'quadraKills': 0,
#     'sightWardsBoughtInGame': 1,
#     'totalDamageDealt': 16997,
#     'totalDamageDealtToChampions': 9387,
#     'totalDamageTaken': 33979,
#     'totalHeal': 1613,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'totalTimeCrowdControlDealt': 579,
#     'totalUnitsHealed': 4,
#     'towerKills': 0,
#     'tripleKills': 0,
#     'trueDamageDealt': 2444,
#     'trueDamageDealtToChampions': 308,
#     'trueDamageTaken': 452,
#     'unrealKills': 0,
#     'visionWardsBoughtInGame': 2,
#     'wardsKilled': 4,
#     'wardsPlaced': 30,
#     'winner': False},
#    'teamId': 200,
#    'timeline': {'creepsPerMinDeltas': {'tenToTwenty': 1.3,
#      'thirtyToEnd': 1.0,
#      'twentyToThirty': 0.7,
#      'zeroToTen': 0.8},
#     'csDiffPerMinDeltas': {'tenToTwenty': 1.6000000000000003,
#      'thirtyToEnd': -2.6,
#      'twentyToThirty': 0.19999999999999996,
#      'zeroToTen': -1.3499999999999999},
#     'damageTakenDiffPerMinDeltas': {'tenToTwenty': 73.25,
#      'thirtyToEnd': 617.6999999999998,
#      'twentyToThirty': 280.05000000000007,
#      'zeroToTen': 220.35000000000002},
#     'damageTakenPerMinDeltas': {'tenToTwenty': 470.4,
#      'thirtyToEnd': 1484.8,
#      'twentyToThirty': 1297.5,
#      'zeroToTen': 479.20000000000005},
#     'goldPerMinDeltas': {'tenToTwenty': 282.2,
#      'thirtyToEnd': 252.4,
#      'twentyToThirty': 251.1,
#      'zeroToTen': 169.4},
#     'lane': 'BOTTOM',
#     'role': 'DUO_SUPPORT',
#     'xpDiffPerMinDeltas': {'tenToTwenty': 108.84999999999997,
#      'thirtyToEnd': -42.600000000000136,
#      'twentyToThirty': -31.44999999999999,
#      'zeroToTen': -47.94999999999999},
#     'xpPerMinDeltas': {'tenToTwenty': 260.6,
#      'thirtyToEnd': 507.8,
#      'twentyToThirty': 328.70000000000005,
#      'zeroToTen': 244.0}}}],
#  'platformId': 'NA1',
#  'queueType': 'RANKED_SOLO_5x5',
#  'region': 'NA',
#  'season': 'SEASON2015',
#  'teams': [{'bans': [{'championId': 64, 'pickTurn': 1},
#     {'championId': 60, 'pickTurn': 3},
#     {'championId': 41, 'pickTurn': 5}],
#    'baronKills': 2,
#    'dominionVictoryScore': 0,
#    'dragonKills': 3,
#    'firstBaron': True,
#    'firstBlood': True,
#    'firstDragon': True,
#    'firstInhibitor': True,
#    'firstTower': True,
#    'inhibitorKills': 3,
#    'teamId': 100,
#    'towerKills': 10,
#    'vilemawKills': 0,
#    'winner': True},
#   {'bans': [{'championId': 114, 'pickTurn': 2},
#     {'championId': 122, 'pickTurn': 4},
#     {'championId': 245, 'pickTurn': 6}],
#    'baronKills': 0,
#    'dominionVictoryScore': 0,
#    'dragonKills': 1,
#    'firstBaron': False,
#    'firstBlood': False,
#    'firstDragon': False,
#    'firstInhibitor': False,
#    'firstTower': False,
#    'inhibitorKills': 0,
#    'teamId': 200,
#    'towerKills': 4,
#    'vilemawKills': 0,
#    'winner': False}],
#  'timeline': {'frameInterval': 60000,
#   'frames': [{'participantFrames': {'1': {'currentGold': 475,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 1,
#       'position': {'x': 561, 'y': 581},
#       'teamScore': 0,
#       'totalGold': 475,
#       'xp': 0},
#      '10': {'currentGold': 515,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 10,
#       'position': {'x': 14237, 'y': 14579},
#       'teamScore': 0,
#       'totalGold': 515,
#       'xp': 0},
#      '2': {'currentGold': 475,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 2,
#       'position': {'x': 561, 'y': 361},
#       'teamScore': 0,
#       'totalGold': 475,
#       'xp': 0},
#      '3': {'currentGold': 475,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 3,
#       'position': {'x': 351, 'y': 293},
#       'teamScore': 0,
#       'totalGold': 475,
#       'xp': 0},
#      '4': {'currentGold': 475,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 4,
#       'position': {'x': 222, 'y': 471},
#       'teamScore': 0,
#       'totalGold': 475,
#       'xp': 0},
#      '5': {'currentGold': 475,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 5,
#       'position': {'x': 311, 'y': 649},
#       'teamScore': 0,
#       'totalGold': 475,
#       'xp': 0},
#      '6': {'currentGold': 475,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 6,
#       'position': {'x': 14486, 'y': 14511},
#       'teamScore': 0,
#       'totalGold': 475,
#       'xp': 0},
#      '7': {'currentGold': 475,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 7,
#       'position': {'x': 14486, 'y': 14291},
#       'teamScore': 0,
#       'totalGold': 475,
#       'xp': 0},
#      '8': {'currentGold': 475,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 8,
#       'position': {'x': 14277, 'y': 14223},
#       'teamScore': 0,
#       'totalGold': 475,
#       'xp': 0},
#      '9': {'currentGold': 475,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 9,
#       'position': {'x': 14148, 'y': 14401},
#       'teamScore': 0,
#       'totalGold': 475,
#       'xp': 0}},
#     'timestamp': 0},
#    {'events': [{'eventType': 'ITEM_PURCHASED',
#       'itemId': 1056,
#       'participantId': 2,
#       'timestamp': 2760},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 1056,
#       'participantId': 3,
#       'timestamp': 3128},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2003,
#       'participantId': 2,
#       'timestamp': 3152},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 1039,
#       'participantId': 1,
#       'timestamp': 3185},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2003,
#       'participantId': 2,
#       'timestamp': 3283},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2003,
#       'participantId': 5,
#       'timestamp': 3767},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2003,
#       'participantId': 1,
#       'timestamp': 3767},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2003,
#       'participantId': 1,
#       'timestamp': 3767},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2041,
#       'participantId': 7,
#       'timestamp': 3801},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 3302,
#       'participantId': 10,
#       'timestamp': 3907},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 1055,
#       'participantId': 5,
#       'timestamp': 4124},
#      {'eventType': 'ITEM_UNDO',
#       'itemAfter': 0,
#       'itemBefore': 1056,
#       'participantId': 3,
#       'timestamp': 4191},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2010,
#       'participantId': 10,
#       'timestamp': 4319},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 3340,
#       'participantId': 2,
#       'timestamp': 4352},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2010,
#       'participantId': 7,
#       'timestamp': 4513},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 3340,
#       'participantId': 5,
#       'timestamp': 4513},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2010,
#       'participantId': 10,
#       'timestamp': 4548},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2010,
#       'participantId': 10,
#       'timestamp': 4740},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2010,
#       'participantId': 7,
#       'timestamp': 4837},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2010,
#       'participantId': 7,
#       'timestamp': 5132},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 3340,
#       'participantId': 1,
#       'timestamp': 5551},
#      {'eventType': 'ITEM_DESTROYED',
#       'itemId': 3599,
#       'participantId': 5,
#       'timestamp': 5618},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 3340,
#       'participantId': 10,
#       'timestamp': 5653},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2010,
#       'participantId': 10,
#       'timestamp': 6299},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 3303,
#       'participantId': 3,
#       'timestamp': 6299},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2004,
#       'participantId': 3,
#       'timestamp': 7470},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 3340,
#       'participantId': 7,
#       'timestamp': 7694},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 3302,
#       'participantId': 6,
#       'timestamp': 7792},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2004,
#       'participantId': 3,
#       'timestamp': 7792},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2003,
#       'participantId': 6,
#       'timestamp': 8023},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2003,
#       'participantId': 6,
#       'timestamp': 8153},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2003,
#       'participantId': 6,
#       'timestamp': 8314},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 3340,
#       'participantId': 3,
#       'timestamp': 8477},
#      {'eventType': 'SKILL_LEVEL_UP',
#       'levelUpType': 'NORMAL',
#       'participantId': 7,
#       'skillSlot': 1,
#       'timestamp': 8477},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 3340,
#       'participantId': 6,
#       'timestamp': 8640},
#      {'eventType': 'SKILL_LEVEL_UP',
#       'levelUpType': 'NORMAL',
#       'participantId': 6,
#       'skillSlot': 2,
#       'timestamp': 10002},
#      {'eventType': 'SKILL_LEVEL_UP',
#       'levelUpType': 'NORMAL',
#       'participantId': 5,
#       'skillSlot': 2,
#       'timestamp': 10069},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 1055,
#       'participantId': 4,
#       'timestamp': 11191},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 1039,
#       'participantId': 8,
#       'timestamp': 12242},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2003,
#       'participantId': 4,
#       'timestamp': 12599},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2003,
#       'participantId': 8,
#       'timestamp': 13018},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 3340,
#       'participantId': 4,
#       'timestamp': 13083},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2003,
#       'participantId': 8,
#       'timestamp': 13277},
#      {'eventType': 'SKILL_LEVEL_UP',
#       'levelUpType': 'NORMAL',
#       'participantId': 10,
#       'skillSlot': 1,
#       'timestamp': 14314},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 3340,
#       'participantId': 8,
#       'timestamp': 15059},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 1054,
#       'participantId': 9,
#       'timestamp': 20009},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2003,
#       'participantId': 9,
#       'timestamp': 20351},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 3340,
#       'participantId': 9,
#       'timestamp': 20873},
#      {'eventType': 'ITEM_PURCHASED',
# ...
#      {'eventType': 'SKILL_LEVEL_UP',
#       'levelUpType': 'NORMAL',
#       'participantId': 5,
#       'skillSlot': 4,
#       'timestamp': 2019977},
#      {'creatorId': 10,
#       'eventType': 'WARD_PLACED',
#       'timestamp': 2020084,
#       'wardType': 'VISION_WARD'},
#      {'eventType': 'ITEM_DESTROYED',
#       'itemId': 2043,
#       'participantId': 10,
#       'timestamp': 2020084},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 1026,
#       'participantId': 2,
#       'timestamp': 2022003},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 3102,
#       'participantId': 4,
#       'timestamp': 2022069},
#      {'eventType': 'ITEM_DESTROYED',
#       'itemId': 3211,
#       'participantId': 4,
#       'timestamp': 2022069},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 1026,
#       'participantId': 6,
#       'timestamp': 2023161},
#      {'creatorId': 8,
#       'eventType': 'WARD_PLACED',
#       'timestamp': 2026528,
#       'wardType': 'SIGHT_WARD'},
#      {'eventType': 'ITEM_DESTROYED',
#       'itemId': 2140,
#       'participantId': 5,
#       'timestamp': 2031817},
#      {'assistingParticipantIds': [1, 4],
#       'eventType': 'CHAMPION_KILL',
#       'killerId': 5,
#       'position': {'x': 8149, 'y': 10689},
#       'timestamp': 2034217,
#       'victimId': 10},
#      {'eventType': 'WARD_KILL',
#       'killerId': 1,
#       'timestamp': 2038886,
#       'wardType': 'VISION_WARD'},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 1028,
#       'participantId': 10,
#       'timestamp': 2039473}],
#     'participantFrames': {'1': {'currentGold': 977,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 74,
#       'level': 15,
#       'minionsKilled': 29,
#       'participantId': 1,
#       'position': {'x': 7919, 'y': 10240},
#       'teamScore': 0,
#       'totalGold': 11162,
#       'xp': 13710},
#      '10': {'currentGold': 80,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 0,
#       'level': 13,
#       'minionsKilled': 33,
#       'participantId': 10,
#       'position': {'x': 8149, 'y': 10689},
#       'teamScore': 0,
#       'totalGold': 8681,
#       'xp': 10872},
#      '2': {'currentGold': 195,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 31,
#       'level': 16,
#       'minionsKilled': 197,
#       'participantId': 2,
#       'position': {'x': 2619, 'y': 719},
#       'teamScore': 0,
#       'totalGold': 13026,
#       'xp': 16432},
#      '3': {'currentGold': 607,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 0,
#       'level': 14,
#       'minionsKilled': 29,
#       'participantId': 3,
#       'position': {'x': 1808, 'y': 11826},
#       'teamScore': 0,
#       'totalGold': 10803,
#       'xp': 12465},
#      '4': {'currentGold': 389,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 11,
#       'level': 18,
#       'minionsKilled': 258,
#       'participantId': 4,
#       'position': {'x': 7463, 'y': 9763},
#       'teamScore': 0,
#       'totalGold': 15476,
#       'xp': 19478},
#      '5': {'currentGold': 649,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 11,
#       'level': 16,
#       'minionsKilled': 205,
#       'participantId': 5,
#       'position': {'x': 6261, 'y': 9599},
#       'teamScore': 0,
#       'totalGold': 14090,
#       'xp': 14922},
#      '6': {'currentGold': 50,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 52,
#       'level': 17,
#       'minionsKilled': 192,
#       'participantId': 6,
#       'position': {'x': 3882, 'y': 12978},
#       'teamScore': 0,
#       'totalGold': 13116,
#       'xp': 18114},
#      '7': {'currentGold': 920,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 0,
#       'level': 14,
#       'minionsKilled': 172,
#       'participantId': 7,
#       'position': {'x': 12796, 'y': 12283},
#       'teamScore': 0,
#       'totalGold': 10261,
#       'xp': 12744},
#      '8': {'currentGold': 1509,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 93,
#       'level': 16,
#       'minionsKilled': 114,
#       'participantId': 8,
#       'position': {'x': 7745, 'y': 858},
#       'teamScore': 0,
#       'totalGold': 13456,
#       'xp': 16102},
#      '9': {'currentGold': 1009,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 7,
#       'level': 14,
#       'minionsKilled': 167,
#       'participantId': 9,
#       'position': {'x': 11571, 'y': 11248},
#       'teamScore': 0,
#       'totalGold': 10674,
#       'xp': 12846}},
#     'timestamp': 2040731},
#    {'events': [{'eventType': 'SKILL_LEVEL_UP',
#       'levelUpType': 'NORMAL',
#       'participantId': 2,
#       'skillSlot': 3,
#       'timestamp': 2048920},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 3047,
#       'participantId': 8,
#       'timestamp': 2049019},
#      {'eventType': 'ITEM_DESTROYED',
#       'itemId': 1001,
#       'participantId': 8,
#       'timestamp': 2049019},
#      {'eventType': 'ITEM_DESTROYED',
#       'itemId': 1029,
#       'participantId': 8,
#       'timestamp': 2049019},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 3047,
#       'participantId': 8,
#       'timestamp': 2049709},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 1028,
#       'participantId': 3,
#       'timestamp': 2049775},
#      {'creatorId': 4,
#       'eventType': 'WARD_PLACED',
#       'timestamp': 2050236,
#       'wardType': 'SIGHT_WARD'},
#      {'eventType': 'ITEM_UNDO',
#       'itemAfter': 0,
#       'itemBefore': 3047,
#       'participantId': 8,
#       'timestamp': 2051157},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 1011,
#       'participantId': 9,
#       'timestamp': 2052440},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 3082,
#       'participantId': 8,
#       'timestamp': 2052890},
#      {'creatorId': 5,
#       'eventType': 'WARD_PLACED',
#       'timestamp': 2053425,
#       'wardType': 'UNDEFINED'},
#      {'eventType': 'SKILL_LEVEL_UP',
#       'levelUpType': 'NORMAL',
#       'participantId': 9,
#       'skillSlot': 2,
#       'timestamp': 2055891},
#      {'eventType': 'SKILL_LEVEL_UP',
#       'levelUpType': 'NORMAL',
#       'participantId': 7,
#       'skillSlot': 3,
#       'timestamp': 2063796},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 1058,
#       'participantId': 7,
#       'timestamp': 2068991},
#      {'creatorId': 3,
#       'eventType': 'WARD_PLACED',
#       'timestamp': 2071502,
#       'wardType': 'SIGHT_WARD'},
#      {'eventType': 'WARD_KILL',
#       'killerId': 8,
#       'timestamp': 2073311,
#       'wardType': 'UNDEFINED'},
#      {'eventType': 'SKILL_LEVEL_UP',
#       'levelUpType': 'NORMAL',
#       'participantId': 6,
#       'skillSlot': 2,
#       'timestamp': 2077373},
#      {'eventType': 'ELITE_MONSTER_KILL',
#       'killerId': 5,
#       'monsterType': 'BARON_NASHOR',
#       'position': {'x': 5007, 'y': 10471},
#       'timestamp': 2077802},
#      {'eventType': 'SKILL_LEVEL_UP',
#       'levelUpType': 'NORMAL',
#       'participantId': 3,
#       'skillSlot': 3,
#       'timestamp': 2082866},
#      {'eventType': 'SKILL_LEVEL_UP',
#       'levelUpType': 'NORMAL',
#       'participantId': 8,
#       'skillSlot': 2,
#       'timestamp': 2083484},
#      {'creatorId': 2,
#       'eventType': 'WARD_PLACED',
#       'timestamp': 2085360,
#       'wardType': 'SIGHT_WARD'},
#      {'creatorId': 4,
#       'eventType': 'WARD_PLACED',
#       'timestamp': 2087681,
#       'wardType': 'SIGHT_WARD'},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 3111,
#       'participantId': 1,
#       'timestamp': 2090813},
#      {'eventType': 'ITEM_DESTROYED',
#       'itemId': 1001,
#       'participantId': 1,
#       'timestamp': 2090813},
#      {'creatorId': 5,
#       'eventType': 'WARD_PLACED',
#       'timestamp': 2096734,
#       'wardType': 'UNDEFINED'}],
#     'participantFrames': {'1': {'currentGold': 516,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 74,
#       'level': 15,
#       'minionsKilled': 29,
#       'participantId': 1,
#       'position': {'x': 4573, 'y': 4236},
#       'teamScore': 0,
#       'totalGold': 11577,
#       'xp': 14472},
#      '10': {'currentGold': 203,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 0,
#       'level': 13,
#       'minionsKilled': 33,
#       'participantId': 10,
#       'position': {'x': 13213, 'y': 5862},
#       'teamScore': 0,
#       'totalGold': 8804,
#       'xp': 10872},
#      '2': {'currentGold': 1134,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 31,
#       'level': 17,
#       'minionsKilled': 219,
#       'participantId': 2,
#       'position': {'x': 13510, 'y': 2909},
#       'teamScore': 0,
#       'totalGold': 13964,
#       'xp': 18158},
#      '3': {'currentGold': 643,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 0,
#       'level': 15,
#       'minionsKilled': 29,
#       'participantId': 3,
#       'position': {'x': 9443, 'y': 8863},
#       'teamScore': 0,
#       'totalGold': 11239,
#       'xp': 13494},
#      '4': {'currentGold': 999,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 11,
#       'level': 18,
#       'minionsKilled': 266,
#       'participantId': 4,
#       'position': {'x': 7538, 'y': 13540},
#       'teamScore': 0,
#       'totalGold': 16086,
#       'xp': 20702},
#      '5': {'currentGold': 1391,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 13,
#       'level': 16,
#       'minionsKilled': 215,
#       'participantId': 5,
#       'position': {'x': 8815, 'y': 8615},
#       'teamScore': 0,
#       'totalGold': 14833,
#       'xp': 15980},
#      '6': {'currentGold': 407,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 56,
#       'level': 18,
#       'minionsKilled': 194,
#       'participantId': 6,
#       'position': {'x': 13405, 'y': 3534},
#       'teamScore': 0,
#       'totalGold': 13473,
#       'xp': 18765},
#      '7': {'currentGold': 79,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 0,
#       'level': 15,
#       'minionsKilled': 182,
#       'participantId': 7,
#       'position': {'x': 9718, 'y': 9147},
#       'teamScore': 0,
#       'totalGold': 10670,
#       'xp': 13193},
#      '8': {'currentGold': 339,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 93,
#       'level': 17,
#       'minionsKilled': 122,
#       'participantId': 8,
#       'position': {'x': 13315, 'y': 3863},
#       'teamScore': 0,
#       'totalGold': 13761,
#       'xp': 16536},
#      '9': {'currentGold': 339,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 8,
#       'level': 15,
#       'minionsKilled': 175,
#       'participantId': 9,
#       'position': {'x': 9149, 'y': 13157},
#       'teamScore': 0,
#       'totalGold': 11004,
#       'xp': 13628}},
#     'timestamp': 2100748},
#    {'events': [{'creatorId': 6,
#       'eventType': 'WARD_PLACED',
#       'timestamp': 2101871,
#       'wardType': 'YELLOW_TRINKET_UPGRADE'},
#      {'assistingParticipantIds': [3],
#       'eventType': 'CHAMPION_KILL',
#       'killerId': 5,
#       'position': {'x': 10182, 'y': 9556},
#       'timestamp': 2104638,
#       'victimId': 7},
#      {'assistingParticipantIds': [6, 10],
#       'eventType': 'CHAMPION_KILL',
#       'killerId': 8,
#       'position': {'x': 13375, 'y': 4124},
#       'timestamp': 2112213,
#       'victimId': 2},
#      {'eventType': 'SKILL_LEVEL_UP',
#       'levelUpType': 'NORMAL',
#       'participantId': 10,
#       'skillSlot': 2,
#       'timestamp': 2116880},
#      {'assistingParticipantIds': [4],
#       'buildingType': 'TOWER_BUILDING',
#       'eventType': 'BUILDING_KILL',
#       'killerId': 5,
#       'laneType': 'TOP_LANE',
#       'position': {'x': 10481, 'y': 13650},
#       'teamId': 200,
#       'timestamp': 2118161,
#       'towerType': 'BASE_TURRET'},
#      {'assistingParticipantIds': [4],
#       'eventType': 'CHAMPION_KILL',
#       'killerId': 5,
#       'position': {'x': 10486, 'y': 13161},
#       'timestamp': 2124878,
#       'victimId': 9},
#      {'eventType': 'ITEM_PURCHASED',
#       'itemId': 2138,
#       'participantId': 8,
#       'timestamp': 2127605},
#      {'eventType': 'ITEM_DESTROYED',
#       'itemId': 2138,
#       'participantId': 8,
#       'timestamp': 2127605},
#      {'eventType': 'SKILL_LEVEL_UP',
#       'levelUpType': 'NORMAL',
#       'participantId': 1,
#       'skillSlot': 4,
#       'timestamp': 2128530},
#      {'buildingType': 'INHIBITOR_BUILDING',
#       'eventType': 'BUILDING_KILL',
#       'killerId': 3,
#       'laneType': 'MID_LANE',
#       'position': {'x': 11598, 'y': 11667},
#       'teamId': 200,
#       'timestamp': 2130145,
#       'towerType': 'UNDEFINED_TURRET'},
#      {'assistingParticipantIds': [1, 4],
#       'buildingType': 'INHIBITOR_BUILDING',
#       'eventType': 'BUILDING_KILL',
#       'killerId': 5,
#       'laneType': 'TOP_LANE',
#       'position': {'x': 11261, 'y': 13676},
#       'teamId': 200,
#       'timestamp': 2131659,
#       'towerType': 'UNDEFINED_TURRET'},
#      {'assistingParticipantIds': [1, 3],
#       'eventType': 'CHAMPION_KILL',
#       'killerId': 4,
#       'position': {'x': 11835, 'y': 12650},
#       'timestamp': 2136827,
#       'victimId': 6},
#      {'assistingParticipantIds': [1, 4, 5],
#       'eventType': 'CHAMPION_KILL',
#       'killerId': 3,
#       'position': {'x': 9651, 'y': 12267},
#       'timestamp': 2142588,
#       'victimId': 8},
#      {'eventType': 'SKILL_LEVEL_UP',
#       'levelUpType': 'NORMAL',
#       'participantId': 3,
#       'skillSlot': 4,
#       'timestamp': 2145088},
#      {'eventType': 'SKILL_LEVEL_UP',
#       'levelUpType': 'NORMAL',
#       'participantId': 5,
#       'skillSlot': 2,
#       'timestamp': 2145554},
#      {'buildingType': 'TOWER_BUILDING',
#       'eventType': 'BUILDING_KILL',
#       'killerId': 4,
#       'laneType': 'MID_LANE',
#       'position': {'x': 13052, 'y': 12612},
#       'teamId': 200,
#       'timestamp': 2146700,
#       'towerType': 'NEXUS_TURRET'},
#      {'assistingParticipantIds': [1, 3, 4],
#       'buildingType': 'TOWER_BUILDING',
#       'eventType': 'BUILDING_KILL',
#       'killerId': 5,
#       'laneType': 'MID_LANE',
#       'position': {'x': 12611, 'y': 13084},
#       'teamId': 200,
#       'timestamp': 2151249,
#       'towerType': 'NEXUS_TURRET'},
#      {'creatorId': 4,
#       'eventType': 'WARD_PLACED',
#       'timestamp': 2154157,
#       'wardType': 'SIGHT_WARD'}],
#     'participantFrames': {'1': {'currentGold': 1062,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 74,
#       'level': 16,
#       'minionsKilled': 30,
#       'participantId': 1,
#       'teamScore': 0,
#       'totalGold': 12122,
#       'xp': 15609},
#      '10': {'currentGold': 462,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 0,
#       'level': 14,
#       'minionsKilled': 33,
#       'participantId': 10,
#       'teamScore': 0,
#       'totalGold': 9062,
#       'xp': 11521},
#      '2': {'currentGold': 1237,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 31,
#       'level': 17,
#       'minionsKilled': 219,
#       'participantId': 2,
#       'teamScore': 0,
#       'totalGold': 14227,
#       'xp': 18158},
#      '3': {'currentGold': 1827,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 0,
#       'level': 16,
#       'minionsKilled': 30,
#       'participantId': 3,
#       'teamScore': 0,
#       'totalGold': 12437,
#       'xp': 15301},
#      '4': {'currentGold': 1918,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 11,
#       'level': 18,
#       'minionsKilled': 275,
#       'participantId': 4,
#       'teamScore': 0,
#       'totalGold': 17208,
#       'xp': 21664},
#      '5': {'currentGold': 2500,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 13,
#       'level': 17,
#       'minionsKilled': 228,
#       'participantId': 5,
#       'teamScore': 0,
#       'totalGold': 16173,
#       'xp': 17460},
#      '6': {'currentGold': 645,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 56,
#       'level': 18,
#       'minionsKilled': 200,
#       'participantId': 6,
#       'teamScore': 0,
#       'totalGold': 13793,
#       'xp': 19201},
#      '7': {'currentGold': 18,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 0,
#       'level': 15,
#       'minionsKilled': 182,
#       'participantId': 7,
#       'teamScore': 0,
#       'totalGold': 10783,
#       'xp': 13193},
#      '8': {'currentGold': 358,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 93,
#       'level': 17,
#       'minionsKilled': 123,
#       'participantId': 8,
#       'teamScore': 0,
#       'totalGold': 14193,
#       'xp': 17022},
#      '9': {'currentGold': 541,
#       'dominionScore': 0,
#       'jungleMinionsKilled': 8,
#       'level': 15,
#       'minionsKilled': 178,
#       'participantId': 9,
#       'teamScore': 0,
#       'totalGold': 11206,
#       'xp': 13838}},
#     'timestamp': 2160748}]}}

# %% [markdown]
# ## Explore data and create features
#
# Plot the length of games

# %%
fig, ax = plt.subplots(1, figsize = [10, 8])
plt.hist(np.array(na_timelines_df[0]['game_length']), bins = range(0, 70), histtype='step', normed=True)
plt.xlabel('Game length (min)')
plt.ylabel('Fraction of games')
lol_plt.prettify_axes(plt.gca())

# %% [markdown]
# Some games don't even last twenty minutes! There is also a large spike of games ending around 20 minutes due to surrenders. When we create features, the feature calculator will have to consider game length.

# %% [markdown]
# ## Create features for gold, kills, towers, and dragons
# Put into pandas dataframe

# %%
na_timelines_df[4][['gold_diff', 'kill_diff', 'tower_diff', 'drag_diff', 'winner', 'game_length']].head(3)
# Out:
#             gold_diff  kill_diff  tower_diff  drag_diff winner  game_length
# matchId
# 1942726245       -232         -1          -1          2      1           35
# 1942729228      10535          7           8          2      1           35
# 1942738358       2406          2           1         -2      0           38

# %% [markdown]
# ## Create a dataframe every 5 minutes

# %%
list(zip(time_indices, np.array([x.shape[0] for x in na_timelines_df])))
# Out:
# [(5, 35783),
#  (10, 35765),
#  (15, 35519),
#  (20, 34655),
#  (25, 28469),
#  (30, 21290),
#  (35, 12341),
#  (40, 5625),
#  (45, 1934),
#  (50, 540)]

# %% [markdown]
# ### How are these features distributed?

# %%
plt.hist(na_timelines_df[4]['gold_diff'].values / 1000, bins = 50, histtype='step')
plt.ylabel('# Games', fontsize = 18)
plt.xlabel('Gold difference (thousands)')
lol_plt.prettify_axes(plt.gca())

# %% [markdown]
# ### Is there correlation between features?

# %%
pd.tools.plotting.scatter_matrix(na_timelines_df[4][['gold_diff', 'kill_diff', 'tower_diff']], figsize = [9, 9]);

# %% [markdown]
# # Which features are important?

# %%
col_names = na_timelines_df[0].columns
train_col = np.array([x for x in col_names if x not in
             ['winner', 'game_length', 'blue_0', 'blue_1', 'blue_2', 'blue_3', 'blue_4',
              'red_0', 'red_1', 'red_2', 'red_3', 'red_4', 'matchId', 'utctimestamp'] ])
num_features = np.size(train_col)
print(train_col, )
# Out:
# ['first_dragon' 'drag_diff' 'total_drag' 'first_baron' 'blue_barons'
#  'red_barons' 'first_tower' 'tower_diff' 'total_tower' 'first_inhib'
#  'blue_inhibs' 'red_inhibs' 'first_blood' 'gold_diff' 'kill_diff'
#  'total_kill' 'blue_share' 'red_share' 'surrender' 'square_gold_diff'
#  'gold_diff_diff' 'tower_diff_diff' 'kill_diff_diff' 'drag_diff_diff']

# %%
feature_importances  = np.zeros([len(na_timelines_df), np.size(train_col)])
for i, cur_df in enumerate(na_timelines_df):
    rfc.fit(cur_df[train_col], cur_df['winner'])
    
    feature_importances[i] = rfc.feature_importances_

# %%
indices_20 = np.argsort(feature_importances[3])[::-1]
plt.imshow(feature_importances[:,indices_20[:-7]], interpolation = 'none',
           extent = [0, num_features*4, 47.5, 2.5])
plt.ylabel('Time (min)', fontsize = 18)
plt.xticks(np.arange(0, (num_features-7)*5.5, 5.5)+3, indices_20[:-7])
x_tick_labels = [str(x) for x in train_col[indices_20[:-7]]]
plt.gca().set_xticklabels(x_tick_labels, rotation = 90)
lol_plt.prettify_axes(plt.gca())
plt.gca().yaxis.set_ticks(time_indices);
plt.colorbar();

# %%
indices_20
# Out:
# array([13, 14, 22, 20,  7, 19, 21,  1, 23, 17,  0, 16,  6, 15,  8, 12,  2,
#        18, 10, 11,  9,  5,  4,  3], dtype=int64)

# %% [markdown]
# # Predict winners using random forests
#
# ### Why random forests?

# %% [markdown]
# It allows me to look at feature importance

# %% [markdown]
# It is resilient to collinearity.

# %% [markdown]
# I had never used it before!

# %%
important_col = ['blue_inhibs', 'blue_barons', 'drag_diff', 'first_baron', 'first_inhib',
                 'gold_diff', 'gold_diff_diff', 'kill_diff', 'kill_diff_diff', 'red_barons',
                 'red_inhibs', 'tower_diff']
timeline_end = 55
time_indices = np.arange(5, timeline_end, 5)

# %%
rfc = RandomForestClassifier(n_estimators = 25, max_features = 'sqrt',
                             min_samples_leaf=10, min_samples_split=25)

def cross_validate_df(cur_df):
    return cross_validation.cross_val_score(rfc, cur_df[important_col], cur_df['winner'],
                                            cv=4, n_jobs = -1)

accuracy_timeline = [cross_validate_df(x) for x in na_timelines_df]

# %%
plt.plot(time_indices, np.mean(accuracy_timeline, 1))
plt.ylim( 0.5, 1)
plt.xlabel('Time (min)')
plt.ylabel('Prediction accuracy')
lol_plt.prettify_axes(plt.gca())

# %% [markdown]
# The game does get more easily predicted with time, as more information is gathered by the model. However, once you reach 30 minutes, the model loses accuracy. This is probably because as the game enters the late phase, gold matters less, and objectives more, and a single decisive teamfight can decide the game either way.

# %% [markdown]
# # Exploring model hyper-parameters
# ### How does model accuracy depend on splitting criterion?

# %%
ten_minute_df = na_timelines_df[2]

# %%
def score_by_min_split(cur_min_split, cur_df):
    split_forest = RandomForestClassifier(n_jobs = -1, n_estimators = 25,
                                          max_features = 'sqrt', min_samples_split = cur_min_split)
    return cross_validation.cross_val_score(split_forest, cur_df[important_col],
                                            cur_df['winner'], cv=10, n_jobs = -1)

min_samples_array = list(range(1, 25, 5))
min_split_scores = list(map(lambda x: score_by_min_split(x, ten_minute_df),
                            min_samples_array))

# %%
plt.errorbar(min_samples_array, np.mean(min_split_scores, 1),
             np.std(min_split_scores, 1) / np.sqrt(5))
lol_plt.prettify_axes(plt.gca())
plt.ylabel('Accuracy at 10 minutes')
plt.xlabel('Minimum samples split')
plt.ylim([0.72, 0.78]);

# %% [markdown]
# # How does skill level impact predictability?

# %%
solo_lengths = np.array( na_timelines_df[0]['game_length'])
team_lengths =np.array( team_timelines_df[0]['game_length'])

# %%
plt.hist(solo_lengths, bins = range(0, 60), histtype='step',
         normed=True, label = 'Solo queue')
plt.hist(team_lengths, bins = range(0, 60), histtype='step',
         normed=True,label = 'Team ranked')
lol_plt.prettify_axes(plt.gca())
plt.xlabel('Game Length')
plt.ylabel('Fraction of Games')
plt.legend(frameon=False, fontsize = 16);

# %% [markdown]
# ## Are team games easier to predict than solo queue games?

# %%
team_scores = [cross_validate_df(x) for x in team_timelines_df]

# %%
plt.errorbar(time_indices[:-2], np.mean(accuracy_timeline[:-2], 1),
             np.std(accuracy_timeline[:-2], 1) / np.sqrt(4), label = 'Solo queue', capsize = 0)
plt.errorbar(time_indices[:-2], np.mean(team_scores[:-2], 1),
             np.std(team_scores[:-2], 1) / np.sqrt(4), label = 'Team ranked', capsize = 0)
lol_plt.prettify_axes(plt.gca())
plt.ylabel('Model accuracy')
plt.xlabel('Minutes in game')
plt.xlim([0, 50])
plt.legend(frameon=False, fontsize=16);

# %% [markdown]
# #What I learned:

# %% [markdown]
# Python requests is pretty great

# %% [markdown]
# Machine learning models need to be optimized

# %% [markdown]
# More stuff!

# %% [markdown]
# # Extra slides!

# %% [markdown]
# ## Are surrendered games winnable?

# %%
surrender_at_20_df = timelines_df[3].query('(surrender == 1) & (game_length <=25)')
good_games_df = timelines_df[3].query('(surrender == 0) | (game_length >25)')
surrender_at_20_df[['surrender', 'game_length']].head(2)
# Out:
#            surrender  game_length
# matchId
# 1947508622         1           22
# 1947379227         1           25

# %%
close_forest = RandomForestClassifier(n_jobs = 3, n_estimators = 20, max_features = 'sqrt')
close_forest.fit(good_games_df[important_col], good_games_df['winner'])
cross_score = np.mean(np.max(close_forest.predict_proba(surrender_at_20_df[important_col]), axis = 1))
print('A forest trained on non-surrender games predicts the team that won would do so with {:.2f} probability'.format(cross_score))
# Out:
# A forest trained on non-surrender games predicts the team that won would do so with 0.93 probability

# %% [markdown]
# ## Forest size versus prediction accuracy

# %%
forest_sizes = np.arange(5, 205, 25)
def score_by_size(cur_size):
    size_forest = RandomForestClassifier(n_jobs = 4, n_estimators = cur_size, max_features = 'sqrt')
    return cross_validation.cross_val_score(size_forest, euw_timelines_df[3][important_col],  euw_timelines_df[3]['winner'], cv=5, n_jobs = 4)

size_scores = list(map(score_by_size, forest_sizes))

# %%
plt.errorbar(forest_sizes, np.mean(size_scores, 1), np.std(size_scores, 1) / np.sqrt(5))
lol_plt.prettify_axes(plt.gca())
plt.ylabel('Accuracy at 35 minutes', fontsize = 18)
plt.xlabel('Number of trees in forest', fontsize = 18)
#plt.ylim([0.8, 0.85]);
